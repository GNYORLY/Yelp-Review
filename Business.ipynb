# %%
import pandas as pd
import numpy as np
from pprint import pprint
import sys
import math

# %%
# Reads the data from CSV files, each attribute column can be obtained via its name, e.g., y = data['y']
def getDataframe(filePath):
    data = pd.read_csv(filePath)
    return data

# %%
business_df = getDataframe('business3.csv')
features = business_df.columns.values

# %%
# find number of unique values for each feature
for feature in features:
    print(feature)
    print(len(business_df[feature].unique()))
# Out:
# address
# 10714
# attributes
# 1
# attributes_AcceptsInsurance
# 3
# attributes_AgesAllowed
# 5
# attributes_Alcohol
# 4
# attributes_Ambience
# 111
# attributes_BYOB
# 3
# attributes_BYOBCorkage
# 4
# attributes_BestNights
# 61
# attributes_BikeParking
# 3
# attributes_BusinessAcceptsBitcoin
# 3
# attributes_BusinessAcceptsCreditCards
# 3
# attributes_BusinessParking
# 33
# attributes_ByAppointmentOnly
# 3
# attributes_Caters
# 3
# attributes_CoatCheck
# 3
# attributes_Corkage
# 3
# attributes_DietaryRestrictions
# 17
# attributes_DogsAllowed
# 3
# attributes_DriveThru
# 3
# attributes_GoodForDancing
# 3
# attributes_GoodForKids
# 3
# attributes_GoodForMeal
# 58
# attributes_HairSpecializesIn
# 37
# attributes_HappyHour
# 3
# attributes_HasTV
# 3
# attributes_Music
# 19
# attributes_NoiseLevel
# 5
# attributes_Open24Hours
# 3
# attributes_OutdoorSeating
# 3
# attributes_RestaurantsAttire
# 4
# attributes_RestaurantsCounterService
# 3
# attributes_RestaurantsDelivery
# 3
# attributes_RestaurantsGoodForGroups
# 3
# attributes_RestaurantsPriceRange2
# 5
# attributes_RestaurantsReservations
# 3
# attributes_RestaurantsTableService
# 3
# attributes_RestaurantsTakeOut
# 3
# attributes_Smoking
# 4
# attributes_WheelchairAccessible
# 3
# attributes_WiFi
# 4
# business_id
# 12058
# categories
# 8943
# city
# 208
# hours
# 1
# hours_Friday
# 623
# hours_Monday
# 579
# hours_Saturday
# 644
# hours_Sunday
# 603
# hours_Thursday
# 598
# hours_Tuesday
# 585
# hours_Wednesday
# 591
# is_open
# 2
# latitude
# 11568
# longitude
# 11495
# name
# 10014
# neighborhood
# 213
# postal_code
# 1574
# review_count
# 1040
# stars
# 9
# state
# 12

# %%
# features to delete from business
elements_to_delete = ['address', 'attributes','city', 'hours', 'hours_Friday','hours_Monday', 'hours_Saturday', 'hours_Sunday', 'hours_Thursday','hours_Tuesday', 'hours_Wednesday', 'is_open', 'latitude','longitude', 'name', 'neighborhood', 'postal_code','state']
# delete features
business_df.drop(elements_to_delete, inplace=True, axis=1)
business_df.columns.values
# Out:
# array(['attributes_AcceptsInsurance', 'attributes_AgesAllowed',
#        'attributes_Alcohol', 'attributes_Ambience', 'attributes_BYOB',
#        'attributes_BYOBCorkage', 'attributes_BestNights',
#        'attributes_BikeParking', 'attributes_BusinessAcceptsBitcoin',
#        'attributes_BusinessAcceptsCreditCards',
#        'attributes_BusinessParking', 'attributes_ByAppointmentOnly',
#        'attributes_Caters', 'attributes_CoatCheck', 'attributes_Corkage',
#        'attributes_DietaryRestrictions', 'attributes_DogsAllowed',
#        'attributes_DriveThru', 'attributes_GoodForDancing',
#        'attributes_GoodForKids', 'attributes_GoodForMeal',
#        'attributes_HairSpecializesIn', 'attributes_HappyHour',
#        'attributes_HasTV', 'attributes_Music', 'attributes_NoiseLevel',
#        'attributes_Open24Hours', 'attributes_OutdoorSeating',
#        'attributes_RestaurantsAttire',
#        'attributes_RestaurantsCounterService',
#        'attributes_RestaurantsDelivery',
#        'attributes_RestaurantsGoodForGroups',
#        'attributes_RestaurantsPriceRange2',
#        'attributes_RestaurantsReservations',
#        'attributes_RestaurantsTableService',
#        'attributes_RestaurantsTakeOut', 'attributes_Smoking',
#        'attributes_WheelchairAccessible', 'attributes_WiFi',
#        'business_id', 'categories', 'review_count', 'stars'], dtype=object)

# %%
business_df.to_csv("business2.csv", encoding='utf-8', index=False)

# %%
# business_df = getDataframe('business2.csv')
print(business_df.shape)
# Out:
# (12058, 43)

# %%
# check value type for each column
features = business_df.columns.values
business_df.dtypes
# Out:
# attributes_AcceptsInsurance               object
# attributes_AgesAllowed                    object
# attributes_Alcohol                        object
# attributes_Ambience                       object
# attributes_BYOB                           object
# attributes_BYOBCorkage                    object
# attributes_BestNights                     object
# attributes_BikeParking                    object
# attributes_BusinessAcceptsBitcoin         object
# attributes_BusinessAcceptsCreditCards     object
# attributes_BusinessParking                object
# attributes_ByAppointmentOnly              object
# attributes_Caters                         object
# attributes_CoatCheck                      object
# attributes_Corkage                        object
# attributes_DietaryRestrictions            object
# attributes_DogsAllowed                    object
# attributes_DriveThru                      object
# attributes_GoodForDancing                 object
# attributes_GoodForKids                    object
# attributes_GoodForMeal                    object
# attributes_HairSpecializesIn              object
# attributes_HappyHour                      object
# attributes_HasTV                          object
# attributes_Music                          object
# attributes_NoiseLevel                     object
# attributes_Open24Hours                    object
# attributes_OutdoorSeating                 object
# attributes_RestaurantsAttire              object
# attributes_RestaurantsCounterService      object
# attributes_RestaurantsDelivery            object
# attributes_RestaurantsGoodForGroups       object
# attributes_RestaurantsPriceRange2        float64
# attributes_RestaurantsReservations        object
# attributes_RestaurantsTableService        object
# attributes_RestaurantsTakeOut             object
# attributes_Smoking                        object
# attributes_WheelchairAccessible           object
# attributes_WiFi                           object
# business_id                               object
# categories                                object
# review_count                               int64
# stars                                    float64
# dtype: object

# %%
# get frequency of values for each feature
for feature in features:
    print('---------------------------------')
    print(feature)
    print(business_df[feature].value_counts(dropna=False))
# Out:
# ---------------------------------
# attributes_AcceptsInsurance
# NaN      11888
# False       99
# True        71
# Name: attributes_AcceptsInsurance, dtype: int64
# ---------------------------------
# attributes_AgesAllowed
# NaN        11992
# 21plus        61
# allages        3
# 19plus         1
# 18plus         1
# Name: attributes_AgesAllowed, dtype: int64
# ---------------------------------
# attributes_Alcohol
# full_bar         4919
# NaN              2800
# none             2613
# beer_and_wine    1726
# Name: attributes_Alcohol, dtype: int64
# ---------------------------------
# attributes_Ambience
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}     5355
# NaN                                                                                                                                                                 2986
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}                      932
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}       404
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}      330
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}     299
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}      187
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}                      127
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}        123
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}       108
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                      96
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}       92
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': False}        70
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}       69
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}                        67
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}       62
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}       57
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': False}       55
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}        52
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}                        46
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}        33
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': False}       30
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                       30
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                       29
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}         26
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': True, 'upscale': False, 'casual': True}         23
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}        22
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}        17
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}                         16
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}        15
#                                                                                                                                                                     ...
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}          1
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}          1
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}           1
# {'romantic': True, 'intimate': True, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': True}             1
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}         1
# {'romantic': True, 'intimate': True, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': True, 'upscale': False, 'casual': False}           1
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}         1
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}          1
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': False}                          1
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}                           1
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': True, 'upscale': True, 'casual': False}           1
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}           1
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}           1
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': True, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}           1
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': True}          1
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}          1
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                         1
# {'romantic': False, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': True}          1
# {'romantic': True, 'intimate': True, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}                           1
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': True, 'casual': False}           1
# {'romantic': False, 'intimate': True, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}          1
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'divey': False, 'touristy': True, 'trendy': False, 'upscale': False, 'casual': True}          1
# {'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}          1
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': False}                         1
# {'romantic': True, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': True, 'casual': True}          1
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}                         1
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': True, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}          1
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': True}                          1
# {'romantic': True, 'intimate': False, 'classy': True, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}          1
# {'romantic': False, 'intimate': True, 'classy': False, 'hipster': False, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}         1
# Name: attributes_Ambience, Length: 111, dtype: int64
# ---------------------------------
# attributes_BYOB
# NaN      11514
# False      515
# True        29
# Name: attributes_BYOB, dtype: int64
# ---------------------------------
# attributes_BYOBCorkage
# NaN            11218
# no               453
# yes_free         272
# yes_corkage      115
# Name: attributes_BYOBCorkage, dtype: int64
# ---------------------------------
# attributes_BestNights
# NaN                                                                                                                                10033
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}         572
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}         431
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}         130
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}          87
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}        74
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}         71
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}        71
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}          68
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}       62
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': False}          38
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': True}          35
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': True, 'saturday': True}          21
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': True, 'saturday': True}          19
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}          19
# {'monday': True, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}          19
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}        18
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}        18
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}          17
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}        16
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}        16
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}        14
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}          14
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}          13
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}          11
# {'monday': True, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}          10
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': False}          10
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}           9
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}          9
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}           8
#                                                                                                                                    ...
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': True}          8
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}           7
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': True, 'saturday': False}           7
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}           6
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': True}          6
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}          6
# {'monday': True, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}           6
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}           5
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}           5
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': True}          5
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}          5
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}           5
# {'monday': False, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}          5
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': False}          4
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': False, 'saturday': False}           4
# {'monday': False, 'tuesday': True, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}          4
# {'monday': True, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}           4
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': True, 'saturday': False}           3
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': True, 'saturday': False}           3
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': True, 'saturday': False}           3
# {'monday': True, 'tuesday': False, 'friday': True, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}          2
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}          2
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}          2
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}          2
# {'monday': True, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}          2
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': True, 'sunday': True, 'saturday': False}           2
# {'monday': True, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': True, 'sunday': False, 'saturday': False}           1
# {'monday': False, 'tuesday': False, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': True, 'saturday': False}          1
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': False}          1
# {'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': True, 'saturday': False}          1
# Name: attributes_BestNights, Length: 61, dtype: int64
# ---------------------------------
# attributes_BikeParking
# True     8797
# False    1799
# NaN      1462
# Name: attributes_BikeParking, dtype: int64
# ---------------------------------
# attributes_BusinessAcceptsBitcoin
# NaN      10246
# False     1772
# True        40
# Name: attributes_BusinessAcceptsBitcoin, dtype: int64
# ---------------------------------
# attributes_BusinessAcceptsCreditCards
# True     11189
# NaN        582
# False      287
# Name: attributes_BusinessAcceptsCreditCards, dtype: int64
# ---------------------------------
# attributes_BusinessParking
# {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}     5644
# {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}     1984
# NaN                                                                                     1283
# {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}     906
# {'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}      603
# {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}       454
# {'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': True}       302
# {'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': False}       203
# {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': True}      130
# {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': True}       101
# {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': True}        73
# {'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': False}        70
# {'garage': True, 'street': True, 'validated': False, 'lot': False, 'valet': True}         56
# {'garage': True, 'street': False, 'validated': False, 'lot': True, 'valet': True}         46
# {'garage': True, 'street': True, 'validated': False, 'lot': True, 'valet': False}         41
# {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': True}         26
# {'garage': True, 'street': False, 'validated': True, 'lot': False, 'valet': False}        21
# {'garage': True, 'street': True, 'validated': False, 'lot': True, 'valet': True}          19
# {'garage': False, 'street': False, 'validated': True, 'lot': False, 'valet': False}       16
# {'garage': True, 'street': True, 'validated': True, 'lot': False, 'valet': False}         16
# {'garage': True, 'street': True, 'validated': True, 'lot': False, 'valet': True}          13
# {'garage': True, 'street': False, 'validated': True, 'lot': True, 'valet': True}           9
# {'garage': False, 'street': True, 'validated': True, 'lot': True, 'valet': True}           7
# {'garage': True, 'street': False, 'validated': True, 'lot': False, 'valet': True}          5
# {'garage': True, 'street': True, 'validated': True, 'lot': True, 'valet': True}            5
# {'garage': True, 'street': False, 'validated': True, 'lot': True, 'valet': False}          5
# {'garage': False, 'street': True, 'validated': True, 'lot': False, 'valet': False}         4
# {'garage': False, 'street': False, 'validated': True, 'lot': True, 'valet': False}         4
# {'garage': False, 'street': True, 'validated': True, 'lot': True, 'valet': False}          3
# {'garage': True, 'street': True, 'validated': True, 'lot': True, 'valet': False}           3
# {'garage': False, 'street': False, 'validated': True, 'lot': False, 'valet': True}         2
# {'garage': False, 'street': True, 'validated': True, 'lot': False, 'valet': True}          2
# {'garage': False, 'street': False, 'validated': True, 'lot': True, 'valet': True}          2
# Name: attributes_BusinessParking, dtype: int64
# ---------------------------------
# attributes_ByAppointmentOnly
# NaN      10720
# False      975
# True       363
# Name: attributes_ByAppointmentOnly, dtype: int64
# ---------------------------------
# attributes_Caters
# True     5014
# False    4254
# NaN      2790
# Name: attributes_Caters, dtype: int64
# ---------------------------------
# attributes_CoatCheck
# NaN      9924
# False    1903
# True      231
# Name: attributes_CoatCheck, dtype: int64
# ---------------------------------
# attributes_Corkage
# NaN      11652
# False      299
# True       107
# Name: attributes_Corkage, dtype: int64
# ---------------------------------
# attributes_DietaryRestrictions
# NaN                                                                                                                                    12003
# {'dairy-free': False, 'gluten-free': False, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}       13
# {'dairy-free': False, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}         7
# {'dairy-free': False, 'gluten-free': True, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': False}        7
# {'dairy-free': True, 'gluten-free': False, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}         5
# {'dairy-free': False, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': False}        5
# {'dairy-free': False, 'gluten-free': True, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}          3
# {'dairy-free': False, 'gluten-free': True, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': False}         3
# {'dairy-free': True, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}          2
# {'dairy-free': False, 'gluten-free': False, 'vegan': False, 'kosher': True, 'halal': False, 'soy-free': False, 'vegetarian': False}        2
# {'dairy-free': True, 'gluten-free': False, 'vegan': True, 'kosher': False, 'halal': False, 'soy-free': True, 'vegetarian': True}           2
# {'dairy-free': False, 'gluten-free': True, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}         1
# {'dairy-free': True, 'gluten-free': True, 'vegan': True, 'kosher': True, 'halal': True, 'soy-free': True, 'vegetarian': True}              1
# {'dairy-free': False, 'gluten-free': False, 'vegan': False, 'kosher': False, 'halal': True, 'soy-free': False, 'vegetarian': True}         1
# {'dairy-free': True, 'gluten-free': True, 'vegan': True, 'kosher': False, 'halal': True, 'soy-free': True, 'vegetarian': True}             1
# {'dairy-free': True, 'gluten-free': True, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': False, 'vegetarian': True}          1
# {'dairy-free': False, 'gluten-free': False, 'vegan': False, 'kosher': False, 'halal': False, 'soy-free': True, 'vegetarian': True}         1
# Name: attributes_DietaryRestrictions, dtype: int64
# ---------------------------------
# attributes_DogsAllowed
# NaN      9324
# False    1937
# True      797
# Name: attributes_DogsAllowed, dtype: int64
# ---------------------------------
# attributes_DriveThru
# NaN      11184
# False      742
# True       132
# Name: attributes_DriveThru, dtype: int64
# ---------------------------------
# attributes_GoodForDancing
# NaN      9810
# False    2006
# True      242
# Name: attributes_GoodForDancing, dtype: int64
# ---------------------------------
# attributes_GoodForKids
# True     7418
# NaN      2547
# False    2093
# Name: attributes_GoodForKids, dtype: int64
# ---------------------------------
# attributes_GoodForMeal
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}      3818
# NaN                                                                                                             3150
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}     1481
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}      530
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}        428
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}        360
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}        324
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}     199
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}       189
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}        178
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': True}       135
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}         107
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}       90
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}       89
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': False}        85
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}         84
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': False}       77
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': True}       69
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}          68
# {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': True}        67
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}           57
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': True}        55
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}          47
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}        44
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': False}          40
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}          29
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}        29
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}        25
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}          22
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': False}        21
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}            19
# {'dessert': True, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': False}         18
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': True}           16
# {'dessert': True, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': False}        10
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': True}         10
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': False}          9
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': True}          9
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}           8
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': True}         6
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': False, 'brunch': True}            6
# {'dessert': True, 'latenight': False, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}           6
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': False}         5
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': False}          5
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': True}          4
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': False, 'brunch': True}          4
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': False}           3
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': True}          3
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': True, 'breakfast': True, 'brunch': False}            3
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': True, 'brunch': False}          3
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': False}          3
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'breakfast': True, 'brunch': True}           2
# {'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': True, 'brunch': True}          2
# {'dessert': True, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': True, 'brunch': True}            2
# {'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': False, 'brunch': True}         1
# {'dessert': True, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': False}          1
# {'dessert': False, 'latenight': True, 'lunch': True, 'dinner': False, 'breakfast': False, 'brunch': True}          1
# {'dessert': True, 'latenight': False, 'lunch': False, 'dinner': True, 'breakfast': True, 'brunch': False}          1
# {'dessert': True, 'latenight': True, 'lunch': False, 'dinner': False, 'breakfast': True, 'brunch': True}           1
# Name: attributes_GoodForMeal, dtype: int64
# ---------------------------------
# attributes_HairSpecializesIn
# NaN                                                                                                                                                          11978
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': True}               15
# {'coloring': False, 'africanamerican': False, 'curly': False, 'perms': False, 'kids': False, 'extensions': False, 'asian': False, 'straightperms': False}        8
# {'coloring': True, 'africanamerican': False, 'curly': False, 'perms': False, 'kids': False, 'extensions': True, 'asian': False, 'straightperms': False}          6
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': True}               6
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': False, 'straightperms': False}           4
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': True, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': True}               3
# {'coloring': False, 'africanamerican': True, 'curly': True, 'perms': False, 'kids': False, 'extensions': False, 'asian': True, 'straightperms': False}           2
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': False, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': True}               2
# {'coloring': False, 'africanamerican': True, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': False}            2
# {'perms': True, 'coloring': True, 'extensions': True, 'curly': True, 'kids': True}                                                                               2
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': True, 'kids': True, 'extensions': False, 'asian': True, 'straightperms': True}               2
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': False}             2
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': False}              2
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': False}               2
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': False, 'straightperms': True}               1
# {'coloring': False, 'africanamerican': True, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': True}               1
# {'coloring': True, 'africanamerican': False, 'curly': False, 'perms': False, 'kids': True, 'extensions': True, 'asian': False, 'straightperms': False}           1
# {'coloring': False, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': False, 'straightperms': False}          1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': False, 'straightperms': False}             1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': False, 'extensions': True, 'asian': False, 'straightperms': True}             1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': True, 'extensions': True, 'asian': True, 'straightperms': False}             1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': True, 'extensions': True, 'asian': False, 'straightperms': True}              1
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': False}             1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': True}             1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': False}            1
# {'coloring': True, 'africanamerican': True, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': False, 'straightperms': False}            1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': True, 'extensions': False, 'asian': True, 'straightperms': True}              1
# {'perms': True, 'coloring': True, 'extensions': False, 'curly': False, 'kids': False}                                                                            1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': False, 'extensions': False, 'asian': False, 'straightperms': False}          1
# {'coloring': False, 'africanamerican': True, 'curly': True, 'perms': False, 'kids': True, 'extensions': False, 'asian': True, 'straightperms': False}            1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': False, 'extensions': False, 'asian': False, 'straightperms': False}           1
# {'coloring': False, 'africanamerican': False, 'curly': True, 'perms': False, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': False}           1
# {'coloring': False, 'africanamerican': False, 'curly': False, 'perms': False, 'kids': True, 'extensions': False, 'asian': False, 'straightperms': False}         1
# {'coloring': True, 'africanamerican': False, 'curly': False, 'perms': False, 'kids': False, 'extensions': False, 'asian': False, 'straightperms': False}         1
# {'coloring': True, 'africanamerican': False, 'curly': True, 'perms': True, 'kids': False, 'extensions': True, 'asian': True, 'straightperms': True}              1
# {'perms': True, 'coloring': True, 'extensions': True, 'curly': False, 'kids': False}                                                                             1
# Name: attributes_HairSpecializesIn, dtype: int64
# ---------------------------------
# attributes_HappyHour
# NaN      9801
# True     1822
# False     435
# Name: attributes_HappyHour, dtype: int64
# ---------------------------------
# attributes_HasTV
# True     5466
# False    3612
# NaN      2980
# Name: attributes_HasTV, dtype: int64
# ---------------------------------
# attributes_Music
# NaN                                                                                                                               9864
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}    1222
# {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}      454
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': False}      220
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}      161
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': True}       84
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': False}        17
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': True, 'live': False, 'video': False, 'jukebox': False}       12
# {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': False}         9
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': True, 'jukebox': False}         4
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': True}         2
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': True}         2
# {'dj': True, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': True, 'video': True, 'jukebox': False}           1
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': False, 'jukebox': True}          1
# {'dj': False, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': False, 'video': True, 'jukebox': True}          1
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': False, 'video': True, 'jukebox': False}        1
# {'dj': False, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': True, 'jukebox': False}         1
# {'dj': True, 'background_music': True, 'no_music': False, 'karaoke': False, 'live': False, 'video': False, 'jukebox': False}         1
# {'dj': True, 'background_music': False, 'no_music': False, 'karaoke': False, 'live': True, 'video': True, 'jukebox': True}           1
# Name: attributes_Music, dtype: int64
# ---------------------------------
# attributes_NoiseLevel
# average      7458
# NaN          3017
# quiet         800
# loud          635
# very_loud     148
# Name: attributes_NoiseLevel, dtype: int64
# ---------------------------------
# attributes_Open24Hours
# NaN      11855
# False      190
# True        13
# Name: attributes_Open24Hours, dtype: int64
# ---------------------------------
# attributes_OutdoorSeating
# True     4955
# False    4379
# NaN      2724
# Name: attributes_OutdoorSeating, dtype: int64
# ---------------------------------
# attributes_RestaurantsAttire
# casual    8365
# NaN       3303
# dressy     389
# formal       1
# Name: attributes_RestaurantsAttire, dtype: int64
# ---------------------------------
# attributes_RestaurantsCounterService
# NaN      11809
# True       144
# False      105
# Name: attributes_RestaurantsCounterService, dtype: int64
# ---------------------------------
# attributes_RestaurantsDelivery
# False    7377
# NaN      3032
# True     1649
# Name: attributes_RestaurantsDelivery, dtype: int64
# ---------------------------------
# attributes_RestaurantsGoodForGroups
# True     8573
# NaN      2969
# False     516
# Name: attributes_RestaurantsGoodForGroups, dtype: int64
# ---------------------------------
# attributes_RestaurantsPriceRange2
#  2.0    7137
#  1.0    2683
# NaN     1268
#  3.0     820
#  4.0     150
# Name: attributes_RestaurantsPriceRange2, dtype: int64
# ---------------------------------
# attributes_RestaurantsReservations
# True     4521
# False    4458
# NaN      3079
# Name: attributes_RestaurantsReservations, dtype: int64
# ---------------------------------
# attributes_RestaurantsTableService
# True     6704
# NaN      3333
# False    2021
# Name: attributes_RestaurantsTableService, dtype: int64
# ---------------------------------
# attributes_RestaurantsTakeOut
# True     8711
# NaN      2614
# False     733
# Name: attributes_RestaurantsTakeOut, dtype: int64
# ---------------------------------
# attributes_Smoking
# NaN        10025
# no          1118
# outdoor      711
# yes          204
# Name: attributes_Smoking, dtype: int64
# ---------------------------------
# attributes_WheelchairAccessible
# True     7875
# NaN      3498
# False     685
# Name: attributes_WheelchairAccessible, dtype: int64
# ---------------------------------
# attributes_WiFi
# free    5112
# no      4340
# NaN     2495
# paid     111
# Name: attributes_WiFi, dtype: int64
# ---------------------------------
# business_id
# a2h9nrVMpNvfwMBo1e8ffg    1
# HpRsWkYHu-pumsZ4O_Linw    1
# r8764MtYyt8JhxMvrfM_xQ    1
# hSyAdVKS9mttVVxMpEQRBQ    1
# Hgy5MrIKrwRJDXnwKaCpbA    1
# vsFFbN71ehRCp46KeR5RdQ    1
# jmeDvVx3wzCBlTBN7XNb-Q    1
# JG9UpsFR6hrqQqsKh_RyaQ    1
# s9CG5XGXJQpP03iYFIHeLA    1
# ohMpNug5zWNxOlL6ShG7Ig    1
# 98F8oDH8Dq8Vr-0zdeSUnQ    1
# FoKx_RP4kUM-aiGo3wlUUw    1
# SW0NcZwZsbSpsk0ZPgJKmQ    1
# XQm5LDv3M9d4zDtKRO_8iQ    1
# jnroKk9qi0FR2bFSkxYZNg    1
# UQMQDq8yuxnyQyBIoKhzoQ    1
# PjEls_NCOQ0m4tJPvcTY8w    1
# svT1TdTgTd4k4-utMCQU8w    1
# 0EUohlWGBPnIgzCULyWl7g    1
# afTRHJ-fvtfADzq94Qk0Sw    1
# ziJsGjXvidzZWC1I0-SOSg    1
# 53GguDU6v46zPJTL3CZl5g    1
# sePTDv1dGHPID7kwuNzXaA    1
# Mie7AsXtQUOEpHTMpk5Z2A    1
# F9_VdKmPyvEcqWSVVGkNNA    1
# xwIJGDiwUz5aorokYKfxIQ    1
# CPi7KGba3x3QjMmIqD4aWw    1
# cTZmf7B-4yciMc1WKiCVOA    1
# 333W59XcrXZsJlnBAAx5mQ    1
# XxYU9t50R5NnyUBmZVCEJg    1
#                          ..
# 0ETtpZSd6f7q_-o-7gutPg    1
# RPYJXaRYEk4Mto7kPhmVnQ    1
# aEtbXqbkf2BnwEVWQ2yjUw    1
# EjzMHfwqAmj7BgdzQjquRQ    1
# RQu_Bv7EFf5NKMnh_3E7Ag    1
# tvwDuDypJDl16icfZDpULg    1
# kJOIif38NQA0ErkcXQAjZw    1
# l4qomOr-2ZDOjWXSZXpzZg    1
# WbbZDPuOEZxFprio05Bb0w    1
# SCklYa_jhihWAcfIn-_chg    1
# burnDlH36FSphvf4vQf10w    1
# LpAdf_z1A9REhTQjr1B4cA    1
# 7tNY4BYLA4laqWNV4IWGQg    1
# KqxJcRmPEdiUTXHwsZcOZw    1
# 0Q8qkmzeiYCTs7taERNHMw    1
# AZveQUZIFuMJWrqmrhqQ4g    1
# ACBC7mTesZDsykfMios-DA    1
# 2EhBiUnUTl_H2s4DXdKCTg    1
# LPCFfrQow0kl7EABuM7VDA    1
# zxSfGIhK3hH3vVz_pS5eaA    1
# xULATz2siGXOPia614mg2A    1
# CIF-zvPmVk-hVqExQmvw-g    1
# wrWdywCI7uLbDb6v07KpKg    1
# IMb5BpDLlSbr7yn19HhltA    1
# aIZQF2UCLv6ru-zsPK4H2Q    1
# ZwnyqSGoqKFg0xe5rY7ChQ    1
# rNoMSO6AsegKb9-p6Ir7SQ    1
# EVl5rbR90yb9vqyq4o5K3A    1
# IrXlXhmSHlIllxZSAARjLA    1
# knU0b5FaqtUSr1UrflaVbg    1
# Name: business_id, Length: 12058, dtype: int64
# ---------------------------------
# categories
# Restaurants, Mexican                                                                                                                                                               155
# Mexican, Restaurants                                                                                                                                                               149
# Chinese, Restaurants                                                                                                                                                                79
# Restaurants, Chinese                                                                                                                                                                70
# Thai, Restaurants                                                                                                                                                                   65
# Restaurants, Italian                                                                                                                                                                57
# Italian, Restaurants                                                                                                                                                                52
# Restaurants, Thai                                                                                                                                                                   51
# Pizza, Restaurants                                                                                                                                                                  47
# Vietnamese, Restaurants                                                                                                                                                             45
# Food, Coffee & Tea                                                                                                                                                                  43
# Restaurants, Pizza                                                                                                                                                                  42
# Restaurants, Vietnamese                                                                                                                                                             39
# Coffee & Tea, Food                                                                                                                                                                  36
# Burgers, Restaurants                                                                                                                                                                33
# Restaurants, Burgers                                                                                                                                                                32
# Restaurants, Breakfast & Brunch                                                                                                                                                     31
# Restaurants, American (New)                                                                                                                                                         30
# Italian, Pizza, Restaurants                                                                                                                                                         29
# Restaurants, American (Traditional)                                                                                                                                                 29
# Cinema, Arts & Entertainment                                                                                                                                                        29
# Restaurants, Sushi Bars, Japanese                                                                                                                                                   28
# Steakhouses, Restaurants                                                                                                                                                            28
# American (New), Restaurants                                                                                                                                                         26
# Performing Arts, Arts & Entertainment                                                                                                                                               26
# Beauty & Spas, Nail Salons                                                                                                                                                          25
# Restaurants, Pizza, Italian                                                                                                                                                         25
# Sushi Bars, Japanese, Restaurants                                                                                                                                                   25
# Japanese, Sushi Bars, Restaurants                                                                                                                                                   25
# Breakfast & Brunch, Restaurants                                                                                                                                                     24
#                                                                                                                                                                                   ...
# Coffee & Tea, Cafes, Desserts, Food, Restaurants, Ice Cream & Frozen Yogurt                                                                                                          1
# Restaurants, Sushi Bars, Japanese, Nightlife, American (New), Bars                                                                                                                   1
# Bakeries, Restaurants, Breakfast & Brunch, Food                                                                                                                                      1
# Drugstores, Shopping, Photography Stores & Services                                                                                                                                  1
# Bars, Nightlife, Lounges, Cocktail Bars, Wine Bars, Beer Bar                                                                                                                         1
# Burgers, American (Traditional), Restaurants, Steakhouses                                                                                                                            1
# American (New), Comfort Food, Breakfast & Brunch, Restaurants                                                                                                                        1
# Nightlife, Bars, American (Traditional), Seafood, Sports Bars, Restaurants                                                                                                           1
# Breakfast & Brunch, American (Traditional), Cafes, Restaurants                                                                                                                       1
# Sandwiches, Cafes, Food, Restaurants, Bakeries, Breakfast & Brunch, Coffee & Tea                                                                                                     1
# Cafes, Restaurants, American (Traditional), Breakfast & Brunch, French, Burgers                                                                                                      1
# Burgers, Breakfast & Brunch, French, Pizza, Restaurants                                                                                                                              1
# Home Services, Drywall Installation & Repair, Contractors, Refinishing Services, Painters                                                                                            1
# Pubs, Burgers, Restaurants, Nightlife, Gastropubs, Sports Bars, Sandwiches, American (New), Beer Bar, Bars                                                                           1
# Restaurants, Breakfast & Brunch, Coffee & Tea, Cocktail Bars, Bars, Food, Cafes, Nightlife                                                                                           1
# Restaurants, Bars, Nightlife, Breweries, American (Traditional), American (New), Sandwiches, Food                                                                                    1
# Emergency Rooms, Hospitals, Medical Centers, Health & Medical, Family Practice, Doctors                                                                                              1
# Auto Insurance, Automotive, Financial Services, Auto Repair, Insurance                                                                                                               1
# Restaurants, Sushi Bars, Noodles, Chinese, Japanese                                                                                                                                  1
# Mediterranean, Greek, Restaurants, Vegetarian                                                                                                                                        1
# Restaurants, Vegetarian, Thai, Vegan                                                                                                                                                 1
# Seafood, Restaurants, Chinese, Cantonese, Dim Sum                                                                                                                                    1
# Brazilian, Steakhouses, Salad, Restaurants, Latin American, Sandwiches                                                                                                               1
# Bars, Nightlife, Restaurants, American (New)                                                                                                                                         1
# Sandwiches, Steakhouses, Specialty Food, Restaurants, Fast Food, American (New), Delis, Cheesesteaks, American (Traditional), Food                                                   1
# Chinese, Restaurants, Indian, Buffets, Halal                                                                                                                                         1
# Nightlife, Beer Gardens, Breweries, Bars, Food, Beer Bar                                                                                                                             1
# Food, Cafes, Restaurants, Beer Bar, Breakfast & Brunch, Wine Bars, Event Planning & Services, Bars, Caterers, Acai Bowls, Coffee & Tea, American (Traditional), Nightlife, Pubs      1
# Restaurants, Sushi Bars, Japanese, Food, Poke                                                                                                                                        1
# NaN                                                                                                                                                                                  1
# Name: categories, Length: 8943, dtype: int64
# ---------------------------------
# review_count
# 100     144
# 103     143
# 102     141
# 104     138
# 101     137
# 112     131
# 106     131
# 111     115
# 108     114
# 110     114
# 115     111
# 109     110
# 118     109
# 113     108
# 107     105
# 105     103
# 134     102
# 122     100
# 116      97
# 128      97
# 132      96
# 114      96
# 117      96
# 124      95
# 119      95
# 121      95
# 123      94
# 126      94
# 139      89
# 120      88
#        ...
# 1059      1
# 1019      1
# 1011      1
# 1003      1
# 979       1
# 971       1
# 963       1
# 955       1
# 931       1
# 923       1
# 907       1
# 1123      1
# 1131      1
# 3250      1
# 3730      1
# 1883      1
# 1867      1
# 3890      1
# 7968      1
# 1819      1
# 1755      1
# 1635      1
# 1219      1
# 1579      1
# 1483      1
# 1419      1
# 1347      1
# 1331      1
# 1299      1
# 2097      1
# Name: review_count, Length: 1040, dtype: int64
# ---------------------------------
# stars
# 4.0    4258
# 3.5    3052
# 4.5    2228
# 3.0    1389
# 2.5     487
# 5.0     416
# 2.0     151
# 1.5      64
# 1.0      13
# Name: stars, dtype: int64

# %%
# delete features with large amount of missing values
elements_to_delete = ['attributes_AcceptsInsurance', 'attributes_AgesAllowed', 'attributes_BYOB', 'attributes_BYOBCorkage', 'attributes_BestNights', 'attributes_BusinessAcceptsBitcoin', 'attributes_ByAppointmentOnly', 'attributes_CoatCheck', 'attributes_Corkage', 'attributes_DietaryRestrictions', 'attributes_DogsAllowed', 'attributes_DriveThru', 'attributes_GoodForDancing', 'attributes_HairSpecializesIn', 'attributes_Music', 'attributes_Open24Hours', 'attributes_RestaurantsCounterService', 'attributes_Smoking', ]
business_df.drop(elements_to_delete, inplace=True, axis=1)
business_df.columns.values
# Out:
# array(['attributes_Alcohol', 'attributes_Ambience',
#        'attributes_BikeParking', 'attributes_BusinessAcceptsCreditCards',
#        'attributes_BusinessParking', 'attributes_Caters',
#        'attributes_GoodForKids', 'attributes_GoodForMeal',
#        'attributes_HappyHour', 'attributes_HasTV',
#        'attributes_NoiseLevel', 'attributes_OutdoorSeating',
#        'attributes_RestaurantsAttire', 'attributes_RestaurantsDelivery',
#        'attributes_RestaurantsGoodForGroups',
#        'attributes_RestaurantsPriceRange2',
#        'attributes_RestaurantsReservations',
#        'attributes_RestaurantsTableService',
#        'attributes_RestaurantsTakeOut', 'attributes_WheelchairAccessible',
#        'attributes_WiFi', 'business_id', 'categories', 'review_count',
#        'stars'], dtype=object)

# %%
business_df.to_csv("business2.csv", encoding='utf-8', index=False)

# %%
business_df = getDataframe('business3.csv')
features = business_df.columns.values
print(business_df.shape)
print(features)
# Out:
# (12058, 61)
# ['address' 'attributes' 'attributes_AcceptsInsurance'
#  'attributes_AgesAllowed' 'attributes_Alcohol' 'attributes_Ambience'
#  'attributes_BYOB' 'attributes_BYOBCorkage' 'attributes_BestNights'
#  'attributes_BikeParking' 'attributes_BusinessAcceptsBitcoin'
#  'attributes_BusinessAcceptsCreditCards' 'attributes_BusinessParking'
#  'attributes_ByAppointmentOnly' 'attributes_Caters' 'attributes_CoatCheck'
#  'attributes_Corkage' 'attributes_DietaryRestrictions'
#  'attributes_DogsAllowed' 'attributes_DriveThru'
#  'attributes_GoodForDancing' 'attributes_GoodForKids'
#  'attributes_GoodForMeal' 'attributes_HairSpecializesIn'
#  'attributes_HappyHour' 'attributes_HasTV' 'attributes_Music'
#  'attributes_NoiseLevel' 'attributes_Open24Hours'
#  'attributes_OutdoorSeating' 'attributes_RestaurantsAttire'
#  'attributes_RestaurantsCounterService' 'attributes_RestaurantsDelivery'
#  'attributes_RestaurantsGoodForGroups' 'attributes_RestaurantsPriceRange2'
#  'attributes_RestaurantsReservations' 'attributes_RestaurantsTableService'
#  'attributes_RestaurantsTakeOut' 'attributes_Smoking'
#  'attributes_WheelchairAccessible' 'attributes_WiFi' 'business_id'
#  'categories' 'city' 'hours' 'hours_Friday' 'hours_Monday'
#  'hours_Saturday' 'hours_Sunday' 'hours_Thursday' 'hours_Tuesday'
#  'hours_Wednesday' 'is_open' 'latitude' 'longitude' 'name' 'neighborhood'
#  'postal_code' 'review_count' 'stars' 'state']

# %%
# store features that need to be factorized in an array
features = np.delete(features, [21, 22, 23, 24])
print(features)
# Out:
# ['address' 'attributes' 'attributes_AcceptsInsurance'
#  'attributes_AgesAllowed' 'attributes_Alcohol' 'attributes_Ambience'
#  'attributes_BYOB' 'attributes_BYOBCorkage' 'attributes_BestNights'
#  'attributes_BikeParking' 'attributes_BusinessAcceptsBitcoin'
#  'attributes_BusinessAcceptsCreditCards' 'attributes_BusinessParking'
#  'attributes_ByAppointmentOnly' 'attributes_Caters' 'attributes_CoatCheck'
#  'attributes_Corkage' 'attributes_DietaryRestrictions'
#  'attributes_DogsAllowed' 'attributes_DriveThru'
#  'attributes_GoodForDancing' 'attributes_HasTV' 'attributes_Music'
#  'attributes_NoiseLevel' 'attributes_Open24Hours'
#  'attributes_OutdoorSeating' 'attributes_RestaurantsAttire'
#  'attributes_RestaurantsCounterService' 'attributes_RestaurantsDelivery'
#  'attributes_RestaurantsGoodForGroups' 'attributes_RestaurantsPriceRange2'
#  'attributes_RestaurantsReservations' 'attributes_RestaurantsTableService'
#  'attributes_RestaurantsTakeOut' 'attributes_Smoking'
#  'attributes_WheelchairAccessible' 'attributes_WiFi' 'business_id'
#  'categories' 'city' 'hours' 'hours_Friday' 'hours_Monday'
#  'hours_Saturday' 'hours_Sunday' 'hours_Thursday' 'hours_Tuesday'
#  'hours_Wednesday' 'is_open' 'latitude' 'longitude' 'name' 'neighborhood'
#  'postal_code' 'review_count' 'stars' 'state']

# %%
# factorize features and replace values
for feature in features:
    feature_values = business_df[feature].value_counts(dropna=False).index.values
    labels, uniques = pd.factorize(feature_values, sort=True)
    business_df[feature].replace(feature_values, labels, inplace=True)

# %%
business_df.head()
# Out:
#    address  attributes  attributes_AcceptsInsurance  attributes_AgesAllowed  \
# 0     7661        -1.0                           -1                      -1
# 1     4142        -1.0                           -1                      -1
# 2     7373        -1.0                           -1                      -1
# 3     3416        -1.0                           -1                      -1
# 4      652        -1.0                           -1                      -1
#
#    attributes_Alcohol  attributes_Ambience  attributes_BYOB  \
# 0                   1                   15               -1
# 1                   1                    1                0
# 2                   1                   12               -1
# 3                   0                    1               -1
# 4                   1                    1               -1
#
#    attributes_BYOBCorkage  attributes_BestNights  attributes_BikeParking  \
# 0                      -1                     -1                       1
# 1                       2                     37                       1
# 2                      -1                     -1                       0
# 3                      -1                     -1                       1
# 4                      -1                     -1                       1
#
#    ...    hours_Wednesday  is_open  latitude  longitude  name  neighborhood  \
# 0  ...                241        0   10705.0    10293.0  7818           121
# 1  ...                 82        1    1929.0     4625.0  6049            -1
# 2  ...                 61        1    9949.0     8135.0  1710            -1
# 3  ...                451        1    8282.0      442.0  5997           167
# 4  ...                 82        1    3603.0     4635.0  5140            -1
#
#    postal_code  review_count  stars  state
# 0         1393            46    6.0      6
# 1          198           177    6.0      1
# 2          172             2    7.0     11
# 3          357           142    6.0      4
# 4          212           130    5.0      1
#
# [5 rows x 61 columns]

# %%
# create a master list of all categories
category_master_list = set()
for value in business_df['categories'].values:
    if isinstance(value, str):
        category_list = value.split(', ')
        category_master_list.update(category_list)
category_master_list = list(category_master_list)
print(category_master_list)
# Out:
# []

# %%
# factorize category_master_list
labels, uniques = pd.factorize(category_master_list, sort=True)

# %%
# replace categories with array of factorized categories
for index, value in business_df['categories'].iteritems():
    if isinstance(value, str):
        category_list = value.split(', ')
        factorized_list = pd.Series(category_list).replace(uniques, labels)
        business_df.at[index, 'categories'] = factorized_list.tolist()

# %%
business_df.to_csv("business3.csv", encoding='utf-8', index=False)

# %%
# replace -1 (missing values) with average values
for feature in features:
    frequency = business_df[feature].value_counts()
    index = np.where(frequency.index.values == -1)
    labels = np.delete(frequency.index.values, index)
    counts = np.delete(frequency.values, index)
    average = (np.multiply(labels, counts).sum())/float(12058)
    business_df[feature].replace(-1, average, inplace=True)

# %%
business_df.head(20)
# Out:
#     address  attributes  attributes_AcceptsInsurance  attributes_AgesAllowed  \
# 0    7661.0         0.0                     0.005888                0.010947
# 1    4142.0         0.0                     0.005888                0.010947
# 2    7373.0         0.0                     0.005888                0.010947
# 3    3416.0         0.0                     0.005888                0.010947
# 4     652.0         0.0                     0.005888                0.010947
# 5     137.0         0.0                     0.005888                0.010947
# 6    7306.0         0.0                     0.005888                0.010947
# 7    9494.0         0.0                     0.005888                0.010947
# 8    3848.0         0.0                     0.005888                0.010947
# 9    7972.0         0.0                     0.005888                0.010947
# 10   7224.0         0.0                     0.005888                0.010947
# 11   8333.0         0.0                     0.005888                0.010947
# 12   7237.0         0.0                     0.005888                0.010947
# 13   2158.0         0.0                     0.005888                0.010947
# 14   3354.0         0.0                     0.005888                0.010947
# 15   9128.0         0.0                     0.005888                0.010947
# 16   9618.0         0.0                     1.000000                0.010947
# 17   1185.0         0.0                     0.005888                0.010947
# 18  10521.0         0.0                     0.005888                0.010947
# 19   3883.0         0.0                     0.005888                0.010947
#
#     attributes_Alcohol  attributes_Ambience  attributes_BYOB  \
# 0              1.00000            15.000000         0.002405
# 1              1.00000             1.000000         0.000000
# 2              1.00000            12.000000         0.002405
# 3              0.00000             1.000000         0.002405
# 4              1.00000             1.000000         0.002405
# 5              0.84135             6.903964         0.002405
# 6              1.00000             1.000000         0.002405
# 7              2.00000            16.000000         0.002405
# 8              0.84135             6.903964         0.002405
# 9              1.00000            42.000000         0.002405
# 10             1.00000             8.000000         0.002405
# 11             1.00000             1.000000         0.002405
# 12             2.00000            16.000000         0.002405
# 13             2.00000            12.000000         0.002405
# 14             1.00000             1.000000         0.002405
# 15             1.00000             1.000000         0.002405
# 16             0.84135             6.903964         0.002405
# 17             1.00000            51.000000         0.002405
# 18             0.00000            16.000000         0.002405
# 19             2.00000             0.000000         0.002405
#
#     attributes_BYOBCorkage  attributes_BestNights  attributes_BikeParking  \
# 0                 0.054653               3.512357                1.000000
# 1                 2.000000              37.000000                1.000000
# 2                 0.054653               3.512357                0.000000
# 3                 0.054653               3.512357                1.000000
# 4                 0.054653               3.512357                1.000000
# 5                 0.054653               3.512357                0.729557
# 6                 0.054653               3.512357                1.000000
# 7                 0.054653               3.512357                1.000000
# 8                 0.054653               3.512357                0.729557
# 9                 0.054653               0.000000                0.000000
# 10                0.054653               0.000000                0.000000
# 11                0.054653              19.000000                1.000000
# 12                0.054653               3.512357                1.000000
# 13                0.054653               3.512357                1.000000
# 14                0.054653               3.512357                1.000000
# 15                0.054653               6.000000                1.000000
# 16                0.054653               3.512357                1.000000
# 17                0.054653               3.512357                1.000000
# 18                0.054653               3.512357                1.000000
# 19                0.054653               3.512357                1.000000
#
#     ...    hours_Wednesday  is_open  latitude  longitude  name  neighborhood  \
# 0   ...              241.0        0   10705.0    10293.0  7818    121.000000
# 1   ...               82.0        1    1929.0     4625.0  6049     58.829242
# 2   ...               61.0        1    9949.0     8135.0  1710     58.829242
# 3   ...              451.0        1    8282.0      442.0  5997    167.000000
# 4   ...               82.0        1    3603.0     4635.0  5140     58.829242
# 5   ...              544.0        1    5845.0     3696.0  1589     58.829242
# 6   ...               82.0        1    9016.0     9826.0  1740    144.000000
# 7   ...              107.0        1   10966.0    11140.0   297     58.829242
# 8   ...              305.0        1    4353.0     8853.0  4870    148.000000
# 9   ...              228.0        1    2712.0     6352.0  2828     58.829242
# 10  ...              357.0        1    9304.0     8247.0  7365    133.000000
# 11  ...               61.0        1    2732.0     4120.0  9692     58.829242
# 12  ...               84.0        1   11001.0    10266.0  1284    206.000000
# 13  ...               39.0        1     278.0     7746.0  3704     58.829242
# 14  ...                0.0        1    7705.0      254.0  1700    203.000000
# 15  ...               84.0        1    5401.0     2209.0  1718    153.000000
# 16  ...              525.0        1    7590.0      592.0  8035    203.000000
# 17  ...              248.0        1    1657.0     4633.0   732     58.829242
# 18  ...                0.0        1   11478.0    11366.0  4498    124.000000
# 19  ...              415.0        0    9451.0     8381.0  1064    117.000000
#
#     postal_code  review_count  stars  state
# 0        1393.0            46    6.0      6
# 1         198.0           177    6.0      1
# 2         172.0             2    7.0     11
# 3         357.0           142    6.0      4
# 4         212.0           130    5.0      1
# 5         321.0            13    6.0      4
# 6          37.0            10    4.0      8
# 7         874.0             5    6.0      6
# 8          76.0             3    5.0      3
# 9         263.0           134    6.0      1
# 10        146.0            14    1.0      5
# 11        290.0           157    5.0      1
# 12        850.0            21    6.0      6
# 13        283.0            47    6.0      1
# 14        349.0           345    5.0      4
# 15        355.0           130    4.0      4
# 16        349.0            32    6.0      4
# 17        198.0            17    7.0      1
# 18        402.0           919    6.0      9
# 19        129.0           122    5.0      5
#
# [20 rows x 61 columns]

# %%
business_df = getDataframe('business3.csv')

# %%
business_df.head()
# Out:
#    address  attributes  attributes_AcceptsInsurance  attributes_AgesAllowed  \
# 0     7661        -1.0                           -1                      -1
# 1     4142        -1.0                           -1                      -1
# 2     7373        -1.0                           -1                      -1
# 3     3416        -1.0                           -1                      -1
# 4      652        -1.0                           -1                      -1
#
#    attributes_Alcohol  attributes_Ambience  attributes_BYOB  \
# 0                   1                   15               -1
# 1                   1                    1                0
# 2                   1                   12               -1
# 3                   0                    1               -1
# 4                   1                    1               -1
#
#    attributes_BYOBCorkage  attributes_BestNights  attributes_BikeParking  \
# 0                      -1                     -1                       1
# 1                       2                     37                       1
# 2                      -1                     -1                       0
# 3                      -1                     -1                       1
# 4                      -1                     -1                       1
#
#    ...    hours_Wednesday  is_open  latitude  longitude  name  neighborhood  \
# 0  ...                241        0   10705.0    10293.0  7818           121
# 1  ...                 82        1    1929.0     4625.0  6049            -1
# 2  ...                 61        1    9949.0     8135.0  1710            -1
# 3  ...                451        1    8282.0      442.0  5997           167
# 4  ...                 82        1    3603.0     4635.0  5140            -1
#
#    postal_code  review_count  stars  state
# 0         1393            46    6.0      6
# 1          198           177    6.0      1
# 2          172             2    7.0     11
# 3          357           142    6.0      4
# 4          212           130    5.0      1
#
# [5 rows x 61 columns]

# %%
# remove square brackets from categories
business_df['categories'] = business_df['categories'].astype('str')
business_df['categories'] = business_df['categories'].map(lambda x: x.lstrip('[').rstrip(']'))
business_df.head()
# Out:
#    address  attributes  attributes_AcceptsInsurance  attributes_AgesAllowed  \
# 0     7661        -1.0                           -1                      -1
# 1     4142        -1.0                           -1                      -1
# 2     7373        -1.0                           -1                      -1
# 3     3416        -1.0                           -1                      -1
# 4      652        -1.0                           -1                      -1
#
#    attributes_Alcohol  attributes_Ambience  attributes_BYOB  \
# 0                   1                   15               -1
# 1                   1                    1                0
# 2                   1                   12               -1
# 3                   0                    1               -1
# 4                   1                    1               -1
#
#    attributes_BYOBCorkage  attributes_BestNights  attributes_BikeParking  \
# 0                      -1                     -1                       1
# 1                       2                     37                       1
# 2                      -1                     -1                       0
# 3                      -1                     -1                       1
# 4                      -1                     -1                       1
#
#    ...    hours_Wednesday  is_open  latitude  longitude  name  neighborhood  \
# 0  ...                241        0   10705.0    10293.0  7818           121
# 1  ...                 82        1    1929.0     4625.0  6049            -1
# 2  ...                 61        1    9949.0     8135.0  1710            -1
# 3  ...                451        1    8282.0      442.0  5997           167
# 4  ...                 82        1    3603.0     4635.0  5140            -1
#
#    postal_code  review_count  stars  state
# 0         1393            46    6.0      6
# 1          198           177    6.0      1
# 2          172             2    7.0     11
# 3          357           142    6.0      4
# 4          212           130    5.0      1
#
# [5 rows x 61 columns]

# %%
business_df.to_csv("business4.csv", encoding='utf-8', index=False)

# %%
business_df['review_count'] = (business_df['review_count']-business_df['review_count'].mean())/business_df['review_count'].std()

# %%
for feature in features:
    business_df[feature].loc[business_df[feature] % 1 != 0] = '?'

# %%
business_df.head(20)
